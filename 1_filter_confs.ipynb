# %% [markdown]
# ## A. Filter out the A/A* conferences

# %%
from collections import defaultdict
import pickle

# %%
import pandas as pd

# %%
df = pd.read_csv('data/CORE.csv', names=['Id', 'Title', 'Acronym', 'Source', 
                                    'Rank', 'hasData', 
                                    'FieldOfResearch', 'Comments', 
                                    'Average Rating'])

# %%
field_of_research_codes = [4602, 4603, 4605, 4608, 4609, 4610, 4611]

# %%
df.head()
# Out:
#      Id                                              Title Acronym    Source  \
# 0  1629  National Conference of the American Associatio...    AAAI  CORE2020
# 1   922  International Joint Conference on Autonomous A...   AAMAS  CORE2020
# 2   196           Association of Computational Linguistics     ACL  CORE2020
# 3    37                                     ACM Multimedia   ACMMM  CORE2020
# 4   147  Architectural Support for Programming Language...  ASPLOS  CORE2020
#
#   Rank hasData  FieldOfResearch  Comments  Average Rating
# 0   A*      No             4602    4603.0          4611.0
# 1   A*     Yes             4602       NaN             NaN
# 2   A*      No             4602       NaN             NaN
# 3   A*      No             4603       NaN             NaN
# 4   A*      No             4612    4606.0             NaN

# %%
core_conf_dfs = df.loc[(df['Rank'].isin(["A*", "A"])) & (df['FieldOfResearch'].isin(field_of_research_codes))]

# %%
len(core_conf_dfs)
# Out:
# 84

# %%
core_conf_dfs['Acronym']
# Out:
# 0       AAAI
# 1      AAMAS
# 2        ACL
# 3      ACMMM
# 7        CHI
#        ...
# 207     SSPR
# 211      TEI
# 216     FAST
# 221     ESWC
# 226    ICDAR
# Name: Acronym, Length: 84, dtype: object

# %%
list(core_conf_dfs['Title'])
# Out:
# ['National Conference of the American Association for Artificial Intelligence',
#  'International Joint Conference on Autonomous Agents and Multiagent Systems (previously the International Conference on Multiagent Systems, ICMAS, changed in 2000)',
#  'Association of Computational Linguistics',
#  'ACM Multimedia',
#  'International Conference on Human Factors in Computing Systems',
#  'Conference on Learning Theory',
#  'IEEE Conference on Computer Vision and Pattern Recognition',
#  'Data Compression Conference',
#  'ACM Conference on Economics and Computation',
#  'Foundations of Genetic Algorithms',
#  'International Conference on Automated Planning and Scheduling',
#  'IEEE International Conference on Computer Vision',
#  'International Conference on Data Engineering',
#  'IEEE International Conference on Data Mining',
#  'International Conference on Machine Learning',
#  'IEEE Information Visualization Conference',
#  'International Joint Conference on Artificial Intelligence',
#  'International Joint Conference on Automated Reasoning',
#  'IEEE International Symposium on Wearable Computers',
#  'ACM International Conference on Knowledge Discovery and Data Mining',
#  'International Conference on the Principles of Knowledge Representation and Reasoning',
#  'Advances in Neural Information Processing Systems (was NIPS)',
#  'IEEE International Conference on Pervasive Computing and Communications',
#  'ACM SIGMOD-SIGACT-SIGART Conference on Principles of Database Systems',
#  'ACM International Conference on Research and Development in Information Retrieval',
#  'ACM Special Interest Group on Management of Data Conference',
#  'Conference in Uncertainty in Artificial Intelligence',
#  'International Conference on Very Large Databases',
#  'ACM International Conference on Web Search and Data Mining',
#  'ACM Conference on Computer Supported Cooperative Work',
#  'ACM International Conference on Information and Knowledge Management',
#  'ACM Special Interest Group on Computer Science Education Conference',
#  'ACM Symposium on User Interface Software and Technology',
#  'Annual Conference of the Cognitive Science Society',
#  'Computer Supported Collaborative Learning',
#  'Conference on Innovative Data Systems Research',
#  'Conference on Computational Natural Language Learning',
#  'Empirical Methods in Natural Language Processing',
#  'European Association of Computational Linguistics',
#  'European Conference on Artificial Intelligence',
#  'European Conference on Computer Vision',
#  'European Conference on Information Retrieval',
#  'European Conference on Machine Learning and Principles and Practice of Knowledge Discovery in Database (PKDD and ECML combined from 2008)',
#  'Interspeech (combined EuroSpeech and ICSLP in 2000)',
#  'Extending Database Technology',
#  'Genetic and Evolutionary Computations',
#  'IEEE International Conference on Fuzzy Systems',
#  'IEEE International Joint Conference on Neural Networks',
#  'IEEE International Symposium on Artificial Life',
#  'IEEE Visualization',
#  'IEEE Workshop on Applications of Computer Vision',
#  'IEEE/RSJ International Conference on Intelligent Robots and Systems',
#  'IFIP TC13 Conference on Human-Computer Interaction',
#  'Intelligent Data Analysis',
#  'International Conference on Advanced Information Systems Engineering',
#  'International Conference on Artificial Intelligence and Statistics',
#  'International Conference on Automated Deduction',
#  'International Conference on Computational Linguistics',
#  'International Conference on Conceptual Modelling',
#  'International Conference on Control, Automation, Robotics and Vision',
#  'International Conference on Cooperative Information Systems',
#  'International Conference on Database Theory',
#  'International Conference on Formal Ontology in Information Systems',
#  'International Conference on Intelligent User Interfaces',
#  'International Conference on Logic Programming and Non-monotonic Reasoning',
#  'International Conference on Neural Information Processing',
#  'International Conference on Principles and Practice of Constraint Programming',
#  'International Conference on Scientific and Statistical Data Base Management',
#  'International Conference on the Simulation and Synthesis of Living Systems',
#  'International Conference on Theory and Applications of Satisfiability Testing',
#  'International Conference on Web Information Systems Engineering',
#  'International Semantic Web Conference',
#  'International Symposium on Robotics Research',
#  'ACM International Conference on Interactive Surfaces and Spaces (was International Workshop on Horizontal Interactive Human-Computer Systems: Tabletop)',
#  'Knowledge capture',
#  'North American Association for Computational Linguistics',
#  'Pacific-Asia Conference on Knowledge Discovery and Data Mining',
#  'Parallel Problem Solving from Nature',
#  'SIAM International Conference on Data Mining',
#  'Structural and Syntactical Pattern Recognition',
#  'Tangible, Embedded, and Embodied Interaction',
#  'Conference on File and Storage Technologies',
#  'Extended Semantic Web Conference (was European Semantic Web Conference)',
#  'IEEE International Conference on Document Analysis and Recognition']

# %%
core_conf_dfs[['Title', 'Acronym']]
# Out:
#                                                  Title Acronym
# 0    National Conference of the American Associatio...    AAAI
# 1    International Joint Conference on Autonomous A...   AAMAS
# 2             Association of Computational Linguistics     ACL
# 3                                       ACM Multimedia   ACMMM
# 7    International Conference on Human Factors in C...     CHI
# ..                                                 ...     ...
# 207     Structural and Syntactical Pattern Recognition    SSPR
# 211       Tangible, Embedded, and Embodied Interaction     TEI
# 216        Conference on File and Storage Technologies    FAST
# 221  Extended Semantic Web Conference (was European...    ESWC
# 226  IEEE International Conference on Document Anal...   ICDAR
#
# [84 rows x 2 columns]

# %%
pwd
# Out:
# '/home/singh_shruti/workspace/meaningful_comparison/comparison_network'

# %%
core_conf_dfs[['Title', 'Acronym']].to_csv('utils/core_astar_confs.csv', index=False)

# %%
df[df['FieldOfResearch'] == 4602]
# Out:
#        Id                                              Title Acronym  \
# 0    1629  National Conference of the American Associatio...    AAAI
# 1     922  International Joint Conference on Autonomous A...   AAMAS
# 2     196           Association of Computational Linguistics     ACL
# 12     14        ACM Conference on Economics and Computation      EC
# 16    546                  Foundations of Genetic Algorithms    FOGA
# ..    ...                                                ...     ...
# 833  1618  Modelling and Optimization: Theory and Applica...   MOPTA
# 848  2183  International Work-conference on the Interplay...  IWINAC
# 852  1682   Portuguese Conference on Artificial Intelligence    EPIA
# 866  2195  European Conference on Evolutionary Computatio...  EvoCOP
# 879  2212              The Symposium of Combinatorial Search    SoCS
#
#        Source            Rank hasData  FieldOfResearch  Comments  \
# 0    CORE2020              A*      No             4602    4603.0
# 1    CORE2020              A*     Yes             4602       NaN
# 2    CORE2020              A*      No             4602       NaN
# 12   CORE2020              A*     Yes             4602    4613.0
# 16   CORE2020              A*      No             4602       NaN
# ..        ...             ...     ...              ...       ...
# 833  CORE2020   National: USA      No             4602       NaN
# 848  CORE2020  National:Spain     Yes             4602       NaN
# 852  CORE2020        Regional     Yes             4602       NaN
# 866  CORE2020        Unranked     Yes             4602       NaN
# 879  CORE2020        Unranked     Yes             4602       NaN
#
#      Average Rating
# 0            4611.0
# 1               NaN
# 2               NaN
# 12              NaN
# 16              NaN
# ..              ...
# 833             NaN
# 848             NaN
# 852             NaN
# 866             NaN
# 879             NaN
#
# [127 rows x 9 columns]

# %% [markdown]
# ## Filter out the A/A* journals

# %%
df_journals = pd.read_csv('data/CORE_journals.csv')

# %%
df_journals.head()
# Out:
#     id                                             title    source rank  \
# 0  356                             ACM Computing Surveys  CORE2020   A*
# 1  518  ACM Transactions on Computer - Human Interaction  CORE2020   A*
# 2  357              ACM Transactions on Computer Systems  CORE2020   A*
# 3  416              ACM Transactions on Database Systems  CORE2020   A*
# 4  155                      ACM Transactions on Graphics  CORE2020   A*
#
#   has changed?  for1   for2  for3      ISSN1      ISSN2 ISSN3 ISSN4
# 0           No   803    NaN   NaN  0360-0300  1557-7341   NaN   NaN
# 1           No   806    NaN   NaN  1073-0516  1557-7325   NaN   NaN
# 2           No   803  806.0   NaN  0734-2071  1557-7333   NaN   NaN
# 3           No   804  806.0   NaN  0362-5915  1557-4644   NaN   NaN
# 4           No   801  806.0   NaN  0730-0301  1557-7368   NaN   NaN

# %%
journals_for = [801, 806, 807]
# ["080101", "080102", "080103", "080104", "080105", 
#                 "080106", "080107", "080108", "080109", "080110", 
#                 "080111", "080112", "080199", "080602", "080604",
#                 "080704", "080705", "080706", "080707"]

# %%
for i in range(1, 10):
    print("08010"+str(i))
# Out:
# 080101
# 080102
# 080103
# 080104
# 080105
# 080106
# 080107
# 080108
# 080109

# %%
core_journals_df = df_journals.loc[(df_journals['rank'].isin(["A*", "A"])) & (df_journals['for1'].isin(journals_for))]

# %%
core_journals_df
# Out:
#       id                                              title    source rank  \
# 1    518   ACM Transactions on Computer - Human Interaction  CORE2020   A*
# 4    155                       ACM Transactions on Graphics  CORE2020   A*
# 9    659  Annual Review of Information Science and Techn...  CORE2020   A*
# 10   156                            Artificial Intelligence  CORE2020   A*
# 11   160                                  Cognitive Science  CORE2020   A*
# 12   161                          Computational Linguistics  CORE2020   A*
# 16   163      IEEE Transactions on Evolutionary Computation  CORE2020   A*
# 17   164                 IEEE Transactions on Fuzzy Systems  CORE2020   A*
# 18   165              IEEE Transactions on Image Processing  CORE2020   A*
# 19   166            IEEE Transactions on Information Theory  CORE2020   A*
# 24   167  IEEE Transactions on Neural Networks and Learn...  CORE2020   A*
# 26   168  IEEE Transactions on Pattern Analysis and Mach...  CORE2020   A*
# 27   835                      IEEE Transactions on Robotics  CORE2020   A*
# 30   520                                Information Systems  CORE2020   A*
# 31   144           International Journal of Computer Vision  CORE2020   A*
# 32   836         International Journal of Robotics Research  CORE2020   A*
# 35   523                  Journal of Information Technology  CORE2020   A*
# 36   147               Journal of Machine Learning Research  CORE2020   A*
# 38   662  Journal of the Association for Information Sci...  CORE2020   A*
# 39   526                                      MIS Quarterly  CORE2020   A*
# 52    73                             Fuzzy Sets and Systems  CORE2020    A
# 60   128                Artificial Intelligence in Medicine  CORE2020    A
# 61   130          Autonomous Agents and Multi-Agent Systems  CORE2020    A
# 62   132                                 BMC Bioinformatics  CORE2020    A
# 63   133                           Computational Complexity  CORE2020    A
# 64   135                       Computer Speech and Language  CORE2020    A
# 65   136            Computer Vision and Image Understanding  CORE2020    A
# 66   137                                        Constraints  CORE2020    A
# 67   139                Data Mining and Knowledge Discovery  CORE2020    A
# 68   140                           Evolutionary Computation  CORE2020    A
# 69   141                           IEEE Intelligent Systems  CORE2020    A
# 70   142  IEEE Transactions on Visualization and Compute...  CORE2020    A
# 71   145        Journal of Artificial Intelligence Research  CORE2020    A
# 72   146                     Journal of Automated Reasoning  CORE2020    A
# 73   149                       Natural Language Engineering  CORE2020    A
# 74   151                                    Neural Networks  CORE2020    A
# 75   154         User Modeling and User Adapted Interaction  CORE2020    A
# 76   169                                   Machine Learning  CORE2020    A
# 98   504            ACM Transactions on Information Systems  CORE2020    A
# 99   507              Information Processing and Management  CORE2020    A
# 100  509       International Journal of Electronic Commerce  CORE2020    A
# 101  510  International Journal of Geographical Informat...  CORE2020    A
# 102  638                                 Electronic Markets  CORE2020    A
# 103  644       International Journal of Medical Informatics  CORE2020    A
# 104  648                            Journal of Informetrics  CORE2020    A
# 105  680                               Information Sciences  CORE2020    A
# 106  693  Journal of the American Medical Informatics As...  CORE2020    A
# 108  832                          Journal of Field Robotics  CORE2020    A
# 109  841     Robotics and Computer Integrated Manufacturing  CORE2020    A
# 110  861    International Journal of Human-Computer Studies  CORE2020    A
#
#     has changed?  for1    for2    for3      ISSN1      ISSN2      ISSN3  \
# 1             No   806     NaN     NaN  1073-0516  1557-7325        NaN
# 4             No   801   806.0     NaN  0730-0301  1557-7368        NaN
# 9             No   807     NaN     NaN  0066-4200  1550-8382        NaN
# 10            No   801  1702.0     NaN  0004-3702  1872-7921        NaN
# 11            No   801  1701.0  1702.0  0364-0213  1551-6709        NaN
# 12            No   801  2004.0  1702.0  0891-2017  1530-9312        NaN
# 16            No   801  1702.0   906.0  1089-778X  1941-0026        NaN
# 17            No   801   906.0     NaN  1063-6706  1941-0034        NaN
# 18            No   801  1702.0   906.0  1057-7149  1941-0042        NaN
# 19            No   801  1702.0   906.0  0018-9448  1557-9654        NaN
# 24            No   801  1702.0   906.0  1045-9227  1941-0093        NaN
# 26            No   801   806.0     NaN  0162-8828        NaN        NaN
# 27            No   801   913.0   906.0  1552-3098  1941-0468        NaN
# 30            No   806     NaN     NaN  0306-4379  1873-6076        NaN
# 31           Yes   801     NaN     NaN  0920-5691  1573-1405        NaN
# 32            No   801   913.0   906.0  0278-3649  1741-3176        NaN
# 35            No   806  1702.0     NaN  0268-3962  1466-4437        NaN
# 36           Yes   801  1702.0     NaN  1532-4435        NaN        NaN
# 38            No   807     NaN     NaN  2330-1635  2330-1643  0002-8231
# 39            No   806     NaN     NaN  0276-7783        NaN        NaN
# 52            No   801   101.0     NaN  0165-0114  1872-6801        NaN
# 60            No   801   903.0     NaN  0933-3657  1873-2860        NaN
# 61            No   801  1702.0     NaN  1387-2532  1573-7454        NaN
# 62            No   801   601.0   802.0  1471-2105        NaN        NaN
# 63            No   801   802.0  1702.0  1016-3328  1420-8954        NaN
# 64            No   801  1702.0     NaN  0885-2308  1095-8363        NaN
# 65            No   801  1702.0     NaN  1077-3142  1090-235X        NaN
# 66            No   801   803.0     NaN  1383-7133  1572-9354        NaN
# 67            No   801   804.0     NaN  1384-5810  1573-756X        NaN
# 68            No   801   103.0   102.0  1063-6560  1530-9304        NaN
# 69            No   801  1702.0     NaN  1541-1672  1941-1294  1094-7167
# 70            No   801   802.0     NaN  1077-2626  1941-0506        NaN
# 71            No   801   102.0     NaN  1076-9757  1943-5037        NaN
# 72            No   801  1702.0     NaN  0168-7433  1573-0670        NaN
# 73            No   801  2004.0  1702.0  1351-3249  1469-8110        NaN
# 74            No   801  1702.0   906.0  0893-6080  1879-2782        NaN
# 75            No   801   806.0     NaN  0924-1868  1573-1391        NaN
# 76           Yes   801  1702.0     NaN  0885-6125  1573-0565        NaN
# 98            No   806     NaN     NaN  1046-8188  1558-2868        NaN
# 99            No   806   807.0     NaN  0306-4573  1873-5371        NaN
# 100           No   806  1503.0     NaN  1086-4415  1557-9301        NaN
# 101           No   806   406.0   909.0  1365-8816  1365-8824  0269-3798
# 102           No   807   806.0     NaN  1019-6781  1422-8890        NaN
# 103           No   807   903.0   806.0  1386-5056  1872-8243        NaN
# 104           No   807     NaN     NaN  1751-1577  1875-5879        NaN
# 105          Yes   807   806.0     NaN  0020-0255  1872-6291  1069-0115
# 106          Yes   807   903.0     NaN  1067-5027  1527-974X        NaN
# 108           No   801   913.0   906.0  1556-4959  1556-4967  0741-2223
# 109           No   801   910.0     NaN  0736-5845        NaN        NaN
# 110           No   806  1702.0  1701.0  1071-5819  1095-9300  1042-8143
#
#          ISSN4
# 1          NaN
# 4          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 24         NaN
# 26         NaN
# 27         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 35         NaN
# 36         NaN
# 38         NaN
# 39         NaN
# 52         NaN
# 60         NaN
# 61         NaN
# 62         NaN
# 63         NaN
# 64         NaN
# 65         NaN
# 66         NaN
# 67         NaN
# 68         NaN
# 69   0885-9000
# 70         NaN
# 71         NaN
# 72         NaN
# 73         NaN
# 74         NaN
# 75         NaN
# 76         NaN
# 98         NaN
# 99         NaN
# 100        NaN
# 101        NaN
# 102        NaN
# 103        NaN
# 104        NaN
# 105        NaN
# 106        NaN
# 108        NaN
# 109        NaN
# 110        NaN

# %%
core_journals_df[['title']].to_csv('utils/core_astar_journals.csv', index=False)

# %% [markdown]
# ## B. Create patterns from the conf and journal names

# %% [markdown]
# ### B.1. Conferences

# %%
# !head utils/core_astar_confs.csv
# Out:
# Title,Acronym
# National Conference of the American Association for Artificial Intelligence,AAAI
# "International Joint Conference on Autonomous Agents and Multiagent Systems (previously the International Conference on Multiagent Systems, ICMAS, changed in 2000)",AAMAS
# Association of Computational Linguistics,ACL
# ACM Multimedia,ACMMM
# International Conference on Human Factors in Computing Systems,CHI
# Conference on Learning Theory,COLT
# IEEE Conference on Computer Vision and Pattern Recognition,CVPR
# Data Compression Conference,DCC
# ACM Conference on Economics and Computation,EC

# %%
acr_conf = defaultdict(list)
title_conf = defaultdict(list)


with open('utils/core_astar_confs.csv', 'r') as f:
    lines = f.readlines()
    
    for _, line in enumerate(lines[1:]):
        splittext = line.rsplit(",", 1)
        title_conf[_].append(splittext[0].strip())
        acr_conf[_].append(splittext[1].strip())

# %%
len(acr_conf), acr_conf
# Out:
# (84,
#  defaultdict(list,
#              {0: ['AAAI'],
#               1: ['AAMAS'],
#               2: ['ACL'],
#               3: ['ACMMM'],
#               4: ['CHI'],
#               5: ['COLT'],
#               6: ['CVPR'],
#               7: ['DCC'],
#               8: ['EC'],
#               9: ['FOGA'],
#               10: ['ICAPS'],
#               11: ['ICCV'],
#               12: ['ICDE'],
#               13: ['ICDM'],
#               14: ['ICML'],
#               15: ['IEEE InfoVis'],
#               16: ['IJCAI'],
#               17: ['IJCAR'],
#               18: ['ISWC'],
#               19: ['KDD'],
#               20: ['KR'],
#               21: ['NeurIPS'],
#               22: ['PERCOM'],
#               23: ['PODS'],
#               24: ['SIGIR'],
#               25: ['SIGMOD'],
#               26: ['UAI'],
#               27: ['VLDB'],
#               28: ['WSDM'],
#               29: ['CSCW'],
#               30: ['CIKM'],
#               31: ['SIGCSE'],
#               32: ['UIST'],
#               33: ['CogSci'],
#               34: ['CSCL'],
#               35: ['CIDR'],
#               36: ['CoNLL'],
#               37: ['EMNLP'],
#               38: ['EACL'],
#               39: ['ECAI'],
#               40: ['ECCV'],
#               41: ['ECIR'],
#               42: ['ECML PKDD'],
#               43: ['Interspeech'],
#               44: ['EDBT'],
#               45: ['GECCO'],
#               46: ['FUZZ-IEEE'],
#               47: ['IJCNN'],
#               48: ['IEEE Alife'],
#               49: ['IEEE VIS'],
#               50: ['WACV'],
#               51: ['IROS'],
#               52: ['Interact'],
#               53: ['IDA'],
#               54: ['CaiSE'],
#               55: ['AISTATS'],
#               56: ['CADE'],
#               57: ['COLING'],
#               58: ['ER'],
#               59: ['ICARCV'],
#               60: ['CoopIS'],
#               61: ['ICDT'],
#               62: ['FOIS'],
#               63: ['IUI'],
#               64: ['LPNMR'],
#               65: ['ICONIP'],
#               66: ['CP'],
#               67: ['SSDBM'],
#               68: ['ALIFE'],
#               69: ['SAT'],
#               70: ['WISE'],
#               71: ['ISWC'],
#               72: ['ISRR'],
#               73: ['ISS'],
#               74: ['K-CAP'],
#               75: ['NAACL'],
#               76: ['PAKDD'],
#               77: ['PPSN'],
#               78: ['SDM'],
#               79: ['SSPR'],
#               80: ['TEI'],
#               81: ['FAST'],
#               82: ['ESWC'],
#               83: ['ICDAR']}))

# %%
for c in [(1, "ICMAS"), (21, "NIPS"), (42,"PKDD"), (42,"ECML"), (43, "EuroSpeech"), (43,"ICSLP"), 
          (59,"ICARCV"), (80,"TEI"), (82,"ESWC"), (73,"ISS")]:
    acr_conf[c[0]].append(c[1])
    acr_conf[c[0]] = list(set(acr_conf[c[0]]))
    
# acr_conf = list(set(acr_conf))

# %%
len(acr_conf)
# Out:
# 89

# %%
len(title_conf), title_conf
# Out:
# (84,
#  defaultdict(list,
#              {0: ['National Conference of the American Association for Artificial Intelligence'],
#               1: ['"International Joint Conference on Autonomous Agents and Multiagent Systems (previously the International Conference on Multiagent Systems, ICMAS, changed in 2000)"'],
#               2: ['Association of Computational Linguistics'],
#               3: ['ACM Multimedia'],
#               4: ['International Conference on Human Factors in Computing Systems'],
#               5: ['Conference on Learning Theory'],
#               6: ['IEEE Conference on Computer Vision and Pattern Recognition'],
#               7: ['Data Compression Conference'],
#               8: ['ACM Conference on Economics and Computation'],
#               9: ['Foundations of Genetic Algorithms'],
#               10: ['International Conference on Automated Planning and Scheduling'],
#               11: ['IEEE International Conference on Computer Vision'],
#               12: ['International Conference on Data Engineering'],
#               13: ['IEEE International Conference on Data Mining'],
#               14: ['International Conference on Machine Learning'],
#               15: ['IEEE Information Visualization Conference'],
#               16: ['International Joint Conference on Artificial Intelligence'],
#               17: ['International Joint Conference on Automated Reasoning'],
#               18: ['IEEE International Symposium on Wearable Computers'],
#               19: ['ACM International Conference on Knowledge Discovery and Data Mining'],
#               20: ['International Conference on the Principles of Knowledge Representation and Reasoning'],
#               21: ['Advances in Neural Information Processing Systems (was NIPS)'],
#               22: ['IEEE International Conference on Pervasive Computing and Communications'],
#               23: ['ACM SIGMOD-SIGACT-SIGART Conference on Principles of Database Systems'],
#               24: ['ACM International Conference on Research and Development in Information Retrieval'],
#               25: ['ACM Special Interest Group on Management of Data Conference'],
#               26: ['Conference in Uncertainty in Artificial Intelligence'],
#               27: ['International Conference on Very Large Databases'],
#               28: ['ACM International Conference on Web Search and Data Mining'],
#               29: ['ACM Conference on Computer Supported Cooperative Work'],
#               30: ['ACM International Conference on Information and Knowledge Management'],
#               31: ['ACM Special Interest Group on Computer Science Education Conference'],
#               32: ['ACM Symposium on User Interface Software and Technology'],
#               33: ['Annual Conference of the Cognitive Science Society'],
#               34: ['Computer Supported Collaborative Learning'],
#               35: ['Conference on Innovative Data Systems Research'],
#               36: ['Conference on Computational Natural Language Learning'],
#               37: ['Empirical Methods in Natural Language Processing'],
#               38: ['European Association of Computational Linguistics'],
#               39: ['European Conference on Artificial Intelligence'],
#               40: ['European Conference on Computer Vision'],
#               41: ['European Conference on Information Retrieval'],
#               42: ['European Conference on Machine Learning and Principles and Practice of Knowledge Discovery in Database (PKDD and ECML combined from 2008)'],
#               43: ['Interspeech (combined EuroSpeech and ICSLP in 2000)'],
#               44: ['Extending Database Technology'],
#               45: ['Genetic and Evolutionary Computations'],
#               46: ['IEEE International Conference on Fuzzy Systems'],
#               47: ['IEEE International Joint Conference on Neural Networks'],
#               48: ['IEEE International Symposium on Artificial Life'],
#               49: ['IEEE Visualization'],
#               50: ['IEEE Workshop on Applications of Computer Vision'],
#               51: ['IEEE/RSJ International Conference on Intelligent Robots and Systems'],
#               52: ['IFIP TC13 Conference on Human-Computer Interaction'],
#               53: ['Intelligent Data Analysis'],
#               54: ['International Conference on Advanced Information Systems Engineering'],
#               55: ['International Conference on Artificial Intelligence and Statistics'],
#               56: ['International Conference on Automated Deduction'],
#               57: ['International Conference on Computational Linguistics'],
#               58: ['International Conference on Conceptual Modelling'],
#               59: ['"International Conference on Control, Automation, Robotics and Vision"'],
#               60: ['International Conference on Cooperative Information Systems'],
#               61: ['International Conference on Database Theory'],
#               62: ['International Conference on Formal Ontology in Information Systems'],
#               63: ['International Conference on Intelligent User Interfaces'],
#               64: ['International Conference on Logic Programming and Non-monotonic Reasoning'],
#               65: ['International Conference on Neural Information Processing'],
#               66: ['International Conference on Principles and Practice of Constraint Programming'],
#               67: ['International Conference on Scientific and Statistical Data Base Management'],
#               68: ['International Conference on the Simulation and Synthesis of Living Systems'],
#               69: ['International Conference on Theory and Applications of Satisfiability Testing'],
#               70: ['International Conference on Web Information Systems Engineering'],
#               71: ['International Semantic Web Conference'],
#               72: ['International Symposium on Robotics Research'],
#               73: ['ACM International Conference on Interactive Surfaces and Spaces (was International Workshop on Horizontal Interactive Human-Computer Systems: Tabletop)'],
#               74: ['Knowledge capture'],
#               75: ['North American Association for Computational Linguistics'],
#               76: ['Pacific-Asia Conference on Knowledge Discovery and Data Mining'],
#               77: ['Parallel Problem Solving from Nature'],
#               78: ['SIAM International Conference on Data Mining'],
#               79: ['Structural and Syntactical Pattern Recognition'],
#               80: ['"Tangible, Embedded, and Embodied Interaction"'],
#               81: ['Conference on File and Storage Technologies'],
#               82: ['Extended Semantic Web Conference (was European Semantic Web Conference)'],
#               83: ['IEEE International Conference on Document Analysis and Recognition']}))

# %%
to_remove = ['"International Joint Conference on Autonomous Agents and Multiagent Systems (previously the International Conference on Multiagent Systems, ICMAS, changed in 2000)"',
            'Advances in Neural Information Processing Systems (was NIPS)',
            'European Conference on Machine Learning and Principles and Practice of Knowledge Discovery in Database (PKDD and ECML combined from 2008)',
            'Interspeech (combined EuroSpeech and ICSLP in 2000)',
            '"International Conference on Control, Automation, Robotics and Vision"',
            'ACM International Conference on Interactive Surfaces and Spaces (was International Workshop on Horizontal Interactive Human-Computer Systems: Tabletop)',
            '"Tangible, Embedded, and Embodied Interaction"',
            'Extended Semantic Web Conference (was European Semantic Web Conference)']

to_add = [(1 ,['International Joint Conference on Autonomous Agents and Multiagent Systems', 'International Conference on Multiagent Systems']), 
          (21, ['Neural Information Processing Systems']),
          (42, ['European Conference on Machine Learning', 'Principles and Practice of Knowledge Discovery in Database']),
          (43, ['Interspeech']), 
          (59, ['International Conference on Control, Automation, Robotics and Vision']),
          (73, ['International Conference on Interactive Surfaces and Spaces', 'International Workshop on Horizontal Interactive Human-Computer Systems']),
          (80, ['Tangible, Embedded, and Embodied Interaction']),
          (82, ['Extended Semantic Web Conference', 'European Semantic Web Conference'])]

# %%
for c in to_add:
    title_conf[c[0]] = c[1]

# %%
len(title_conf), len(acr_conf)
# Out:
# (84, 84)

# %% [markdown]
# ### B.2 Fuzzy search for names

# %%
# !pip3 install --user fuzzysearch
# !pip3 install --user fuzzywuzzy
# Out:
# Collecting fuzzysearch
#   Downloading https://files.pythonhosted.org/packages/f7/28/3e9e4e55fd35356f331a22976694e151eb0214b68d3cd471936f9c09deba/fuzzysearch-0.7.3.tar.gz (112kB)
#     100% |████████████████████████████████| 122kB 1.5MB/s ta 0:00:01
# Requirement already satisfied: attrs>=19.3 in /usr/local/lib/python3.6/site-packages (from fuzzysearch)
# Building wheels for collected packages: fuzzysearch
#   Running setup.py bdist_wheel for fuzzysearch ... done
#   Stored in directory: /home/singh_shruti/.cache/pip/wheels/6b/28/23/87d8b2c68b65300ac30e13b019f0589dc38b88ed983010155f
# Successfully built fuzzysearch
# Installing collected packages: fuzzysearch
# Successfully installed fuzzysearch-0.7.3
# Collecting fuzzywuzzy
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/43/ff/74f23998ad2f93b945c0309f825be92e04e0348e062026998b5eefef4c33/fuzzywuzzy-0.18.0-py2.py3-none-any.whl
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
from fuzzywuzzy import fuzz
# Out:
# /home/singh_shruti/.local/lib/python3.6/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
fuzz.partial_ratio("Proceedings of the Annual Meeting of the Cognitive Science Society".lower(), 
                                  "Annual Conference of the Cognitive Science Society".lower())
# Out:
# 85

# %%
fuzz.partial_ratio("ECAI Workshop on Knowledge Representation and Reasoning".lower(), "International Conference on the Principles of Knowledge Representation and Reasoning".lower())
# Out:
# 82

# %%
fuzz.partial_ratio("Conference on Speech and Language Processing".lower(), "ACM Transactions on Speech and Language Processing".lower())
# Out:
# 88

# %% [markdown]
# ### B.3. Journals

# %%
# !wc -l utils/core_astar_journals.csv
# Out:
# 51 utils/core_astar_journals.csv

# %%
# !head -20 utils/core_astar_journals.csv
# Out:
# title
# ACM Transactions on Computer - Human Interaction
# ACM Transactions on Graphics
# Annual Review of Information Science and Technology
# Artificial Intelligence
# Cognitive Science
# Computational Linguistics
# IEEE Transactions on Evolutionary Computation
# IEEE Transactions on Fuzzy Systems
# IEEE Transactions on Image Processing
# IEEE Transactions on Information Theory
# IEEE Transactions on Neural Networks and Learning Systems (was IEEE Transactions on Neural Networks)
# IEEE Transactions on Pattern Analysis and Machine Intelligence
# IEEE Transactions on Robotics
# Information Systems
# International Journal of Computer Vision
# International Journal of Robotics Research
# Journal of Information Technology
# Journal of Machine Learning Research
# Journal of the Association for Information Science and Technology (was Journal of the American Society for Information Science and Technology)

# %%
# Journal titles are exact matches 

title_journ = defaultdict(list)

with open('utils/core_astar_journals.csv', 'r') as f:
    lines = f.readlines()
    
    for _, line in enumerate(lines[1:]):
        line = line.strip()
        splittext = line.split(" (was ", )
#         print(splittext)
        title_journ[_+84].append(splittext[0].strip())
        if len(splittext) > 1:
            title_journ[_+84].append(splittext[1][:-1].strip())

# %%
title_journ
# Out:
# defaultdict(list,
#             {84: ['ACM Transactions on Computer - Human Interaction'],
#              85: ['ACM Transactions on Graphics'],
#              86: ['Annual Review of Information Science and Technology'],
#              87: ['Artificial Intelligence'],
#              88: ['Cognitive Science'],
#              89: ['Computational Linguistics'],
#              90: ['IEEE Transactions on Evolutionary Computation'],
#              91: ['IEEE Transactions on Fuzzy Systems'],
#              92: ['IEEE Transactions on Image Processing'],
#              93: ['IEEE Transactions on Information Theory'],
#              94: ['IEEE Transactions on Neural Networks and Learning Systems',
#               'IEEE Transactions on Neural Networks'],
#              95: ['IEEE Transactions on Pattern Analysis and Machine Intelligence'],
#              96: ['IEEE Transactions on Robotics'],
#              97: ['Information Systems'],
#              98: ['International Journal of Computer Vision'],
#              99: ['International Journal of Robotics Research'],
#              100: ['Journal of Information Technology'],
#              101: ['Journal of Machine Learning Research'],
#              102: ['Journal of the Association for Information Science and Technology',
#               'Journal of the American Society for Information Science and Technology'],
#              103: ['MIS Quarterly'],
#              104: ['Fuzzy Sets and Systems'],
#              105: ['Artificial Intelligence in Medicine'],
#              106: ['Autonomous Agents and Multi-Agent Systems'],
#              107: ['BMC Bioinformatics'],
#              108: ['Computational Complexity'],
#              109: ['Computer Speech and Language'],
#              110: ['Computer Vision and Image Understanding'],
#              111: ['Constraints'],
#              112: ['Data Mining and Knowledge Discovery'],
#              113: ['Evolutionary Computation'],
#              114: ['IEEE Intelligent Systems'],
#              115: ['IEEE Transactions on Visualization and Computer Graphics'],
#              116: ['Journal of Artificial Intelligence Research'],
#              117: ['Journal of Automated Reasoning'],
#              118: ['Natural Language Engineering'],
#              119: ['Neural Networks'],
#              120: ['User Modeling and User Adapted Interaction'],
#              121: ['Machine Learning'],
#              122: ['ACM Transactions on Information Systems'],
#              123: ['Information Processing and Management'],
#              124: ['International Journal of Electronic Commerce'],
#              125: ['International Journal of Geographical Information Science'],
#              126: ['Electronic Markets'],
#              127: ['International Journal of Medical Informatics'],
#              128: ['Journal of Informetrics'],
#              129: ['Information Sciences'],
#              130: ['Journal of the American Medical Informatics Association'],
#              131: ['Journal of Field Robotics'],
#              132: ['Robotics and Computer Integrated Manufacturing'],
#              133: ['International Journal of Human-Computer Studies']})

# %% [markdown]
# ### C. Save the conf/jounral dicts

# %%
import pickle

# %%
with open('utils/conf_acr_dict.pkl', 'wb') as f:
    pickle.dump(acr_conf, f)
    
with open('utils/conf_title_dict.pkl', 'wb') as f:
    pickle.dump(title_conf, f)
    
with open('utils/jour_title_dict.pkl', 'wb') as f:
    pickle.dump(title_journ, f)

# %% [markdown]
# ## D. Create unified dict

# %%
with open('utils/conf_acr_dict.pkl', 'rb') as f:
    conf_acr = pickle.load(f)
    
with open('utils/conf_title_dict.pkl', 'rb') as f:
    conf_title = pickle.load(f)
    
with open('utils/jour_title_dict.pkl', 'rb') as f:
    jour_title = pickle.load(f)

# %%
c_j_dict = {'max_counter': 0, 'confs': conf_title, 'jours': jour_title, 'acronyms': conf_acr}
c_j_dict['max_counter'] = len(c_j_dict['confs']) + len(c_j_dict['jours'])

# %%
with open('data/venue_ids.pkl', 'wb') as f:
    pickle.dump(c_j_dict, f)

# %%
c_j_dict['max_counter']
# Out:
# 134

# %%
def add_new_venue(c_j_dict, venue_name, is_conf=True, acr=None):
    new_idx = c_j_dict['max_counter']
    try:
        if is_conf:
            c_j_dict['confs'].update({new_idx: venue_name})
        else:
            c_j_dict['jours'].update({new_idx: venue_name})
        
        if acr:
            c_j_dict['acronyms'].update({new_idx: acr})
        
        c_j_dict['max_counter'] = new_idx + 1
    except Exception as ex:
        return
    return c_j_dict

# %%
c_j_dict = add_new_venue(c_j_dict, "International Conference on Learning Representations", is_conf=True, acr='ICLR')

# %%
c_j_dict['max_counter']
# Out:
# 135

# %%
with open('data/venue_ids.pkl', 'wb') as f:
    pickle.dump(c_j_dict, f)
